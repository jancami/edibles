# %%
# The usual suspects
import numpy as np
import matplotlib.pyplot as plt

# The EDIBLES bits that find files and load spectra
from edibles.utils.edibles_oracle import EdiblesOracle
from edibles.utils.edibles_spectrum import EdiblesSpectrum

import sys
import os

gui_path = os.path.abspath(os.path.join(os.getcwd(), '..'))

if gui_path not in sys.path:
 sys.path.insert(0, gui_path)

# Our project's own helpers (these live in the same folder as this notebook)
from flux_wave_find import wave_flux_data
from co_adding_flux import coadd_spectra
from main_run import get_species_data, astrovoigtfit_run
from main import master_function
from edibles.projects.edr5_integration import transformations

# Make the plots a bit less ugly
plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['figure.dpi'] = 100
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.3

print('All imports happy. Onward.')
# Out:
# All imports happy. Onward.

# %%
star_name = 'HD 24398'
target_wave = 7698.965         # rest wavelength of the K_7699 line
wrange = [7697.0, 7700.0]       # window around the line for loading data

# Show every species the code already knows about
all_species = get_species_data('species.txt')
print('Species I know about:')
for name, info in all_species.items():
    print(f"  {name:20s} line={info['line']}  wrange={info['wrange']}")
# Out:
# Species I know about:
#   K_4044               line=4044.142  wrange=[4043.0, 4045.0]
#   K_7699               line=7698.965  wrange=[7697.0, 7700.0]
#   12CH+_4032           line=4232.548  wrange=[4231.5, 4233.5]
#   13CH+_4032           line=4232.548  wrange=[4231.5, 4233.5]
#   7Li_6707             line=6707.761  wrange=[6707.1, 6708.2]
#   6Li_6707             line=6707.761  wrange=[6707.1, 6708.2]
#   Na_D_5892            line=5889.951  wrange=[5889.0, 5897.0]
#   85Rb_7800            line=7800.250  wrange=[7798.0, 7800.9]
#   87Rb_7800            line=7800.250  wrange=[7798.0, 7800.9]

# %%
oracle = EdiblesOracle()
files = oracle.getFilteredObsList([star_name], Wave=target_wave, MergedOnly=False)

# Turn it into a plain list so we can index it like normal humans
if hasattr(files, 'tolist'):
    files = files.tolist()

print(f'Found {len(files)} files covering {target_wave} A for {star_name}:\n')
for i, f in enumerate(files):
    print(f'  [{i}]  {f}')
# Out:
# ***Common Objects***
# ['HD 24398']
# **Filtered File List**
# 23286    orders/HD24398_2017-09-05T08:56:25_860nm_redl_...
# 23440    orders/HD24398_2014-09-25T08:09:19_860nm_redl_...
# 23503    combined/HD24398_2017-09-05T08:56:25_860nm_red...
# 23510    combined/HD24398_2014-09-25T08:09:19_860nm_red...
# Name: Filename, dtype: str
# 4
# Found 4 files covering 7698.965 A for HD 24398:
#
#   [0]  orders/HD24398_2017-09-05T08:56:25_860nm_redl_O13.fits
#   [1]  orders/HD24398_2014-09-25T08:09:19_860nm_redl_O13.fits
#   [2]  combined/HD24398_2017-09-05T08:56:25_860nm_redl.fits
#   [3]  combined/HD24398_2014-09-25T08:09:19_860nm_redl.fits

# %%
# Code for fitting just one spectrum
selected_index = 0

# Pull each spectrum from disk (just the wavelength window, median normalized)
wave_list = []
flux_list = []

# for i in [selected_index]:
#    fname = files[i]
w, f = wave_flux_data(star_name=star_name, wave=target_wave, wrange=wrange, file_name=r"orders/HD24398_2014-09-25T08:09:19_860nm_redl_O13.fits")
#    if w is None or len(w) == 0:
#        print(f'Skipping file {i}: no data in range')
#        continue
#    wave_list.append(w)
#    flux_list.append(f)
#    print(f'Loaded file {i}: {len(w)} points')

# Quick look so you can spot weirdos
plt.figure()
# for i, (w, f) in enumerate(zip(wave_list, flux_list)):
plt.plot(w, f, alpha=0.6, label=f'file {selected_index}')
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux (median normalized)')
plt.title(f'Individual spectrum for {star_name}')
plt.legend()
plt.show()

# %%
sigma_per_spectrum = 0.002   # noise estimate per individual spectrum

# wave_coadd, flux_coadd, sigma_coadd = coadd_spectra(
#    wave_list, flux_list, sigma_list=sigma_per_spectrum)

w, f = wave_flux_data(star_name=star_name, wave=target_wave,
 wrange=wrange, file_name=r"orders/HD24398_2014-09-25T08:09:19_860nm_redl_O13.fits")
if w is None or len(w) == 0:
 print(f'No data in range for file {selected_index}')
else:
 print(f'Loaded file {selected_index}: {len(w)} points')
# Out:
# Loaded file 0: 87 points

# %%
fit_range = (7698.4, 7699.8)
absorption_range = (7699.14, 7699.5)

plt.figure()
plt.plot(w, f, color='black', lw=1)
plt.axvspan(*fit_range, color='blue', alpha=0.1, label='fit range')
plt.axvspan(*absorption_range, color='red', alpha=0.2, label='absorption range')
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux')
plt.title('Sanity check: are your ranges in the right place?')
plt.legend()
plt.show()

# Crop the data to the fit range so we hand only the relevant chunk to the fitter
mask = (w >= fit_range[0]) & (w <= fit_range[1])
wave_fit = w[mask]
flux_fit = f[mask]
print(f'After cropping to fit range: {len(wave_fit)} points')
# Out:
# After cropping to fit range: 41 points

# %%
# Flavor A: auto, equidistant knots, just say how many
n_knots = 0
# knots_x_array = None

# Flavor B: manual, you say exactly where every knot goes
# Uncomment the next line to use manual mode (it overrides n_knots)
knots_x_array = [7698.4, 7698.6, 7698.84, 7698.96, 7699.05, 7699.65, 7699.8]

spline_order = 1   # 1 linear, 2 quadratic, 3 cubic

# Preview where the knots would land
if knots_x_array is None:
    preview_knots = np.linspace(fit_range[0], fit_range[1], n_knots)
    inside_abs = (preview_knots >= absorption_range[0]) & (preview_knots <= absorption_range[1])
    preview_knots = preview_knots[~inside_abs]
    preview_knots = np.sort(np.unique(np.append(
        preview_knots, [absorption_range[0] - 0.05, absorption_range[1] + 0.05])))
    knot_label = f'{len(preview_knots)} auto knots (fitter may tweak)'
else:
    preview_knots = np.asarray(knots_x_array)
    knot_label = f'{len(preview_knots)} manual knots'

plt.figure()
plt.plot(wave_fit, flux_fit, color='black', lw=1)
plt.axvspan(*absorption_range, color='red', alpha=0.2, label='absorption range')
plt.vlines(preview_knots, flux_fit.min(), flux_fit.max(),
           colors='orange', linestyles=':', label=knot_label)
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux')
plt.title('Knot preview')
plt.legend()
plt.show()
print(knots_x_array)
# Out:
# [7698.4, 7698.6, 7698.84, 7698.96, 7699.05, 7699.65, 7699.8]

# %%
molecules = ['K_7699'] #this should match with the first column of species.txt

species_params = {
    0: {
        'b':     [1.5],
        'N':     [5e12],
        'v_rad': [14],
    } #,   # uncomment if you have  second species
    # 1: {
    #     'b':     [2.0, 2.0],
    #     'N':     [1e12, 1e12],
    #     'v_rad': [5,5],
    # }
}

 

print(f"You're fitting {len(molecules)} species with these components:")
for i, mol in enumerate(molecules):
    p = species_params[i]
    print(f"  {mol}: {len(p['b'])} component(s)")
    print(f"    b     = {p['b']}")
    print(f"    N     = {p['N']}")
    print(f"    v_rad = {p['v_rad']}")
# Out:
# You're fitting 1 species with these components:
#   K_7699: 1 component(s)
#     b     = [1.5]
#     N     = [5000000000000.0]
#     v_rad = [14]

# %%
fit_std_dev = 0.004 # standard dev of the co-added spectra 
# this is a very important parameter... ideally you should find 
# this by taking a wavelength region from the spectra where the continuum
# is pretty flatt with almost no absorption and fitting it 
# with a line and find the stardard dev of the data points 

fitresult, normalized_flux, continuum, residual_std = astrovoigtfit_run(
    wave_fit, flux_fit, molecules, species_params,
    absorption_range, n_knots=n_knots, knots_x_array=knots_x_array,
    species_file='species.txt', spline_order=spline_order,
    std_dev=fit_std_dev,
)

print(f'\nFit success:        {fitresult.success}')
print(f'Chi square:         {fitresult.chisqr:.4f}')
print(f'Reduced chi square: {fitresult.redchi:.4f}')
print(f'Std of residuals:   {residual_std:.5f}')
# Out:
# Species: K_7699, Lambda: [7698.965], f: [0.3331], Gamma: [37400000.0]
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.5]), 'N_1st': array([5.e+12]), 'v_rad_1st': array([14.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.5]), 'N_1st': array([5.e+12]), 'v_rad_1st': array([14.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.5]), 'N_1st': array([5.e+12]), 'v_rad_1st': array([14.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.5]), 'N_1st': array([5.e+12]), 'v_rad_1st': array([14.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.50001219]), 'N_1st': array([5.e+12]), 'v_rad_1st': array([14.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.5]), 'N_1st': array([5.00005e+12]), 'v_rad_1st': array([14.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.5]), 'N_1st': array([5.e+12]), 'v_rad_1st': array([14.00014])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.15443783]), 'N_1st': array([8.05457264e+13]), 'v_rad_1st': array([12.69829744])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.44913062]), 'N_1st': array([1.90484164e+13]), 'v_rad_1st': array([13.97050707])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36197276]), 'N_1st': array([2.50843563e+12]), 'v_rad_1st': array([14.04209])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36198584]), 'N_1st': array([2.50843563e+12]), 'v_rad_1st': array([14.04209])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36197276]), 'N_1st': array([2.50841055e+12]), 'v_rad_1st': array([14.04209])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36197276]), 'N_1st': array([2.50843563e+12]), 'v_rad_1st': array([14.04223042])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.3390407]), 'N_1st': array([1.23935644e+12]), 'v_rad_1st': array([14.04173356])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.33905391]), 'N_1st': array([1.23935644e+12]), 'v_rad_1st': array([14.04173356])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.3390407]), 'N_1st': array([1.23936883e+12]), 'v_rad_1st': array([14.04173356])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.3390407]), 'N_1st': array([1.23935644e+12]), 'v_rad_1st': array([14.04187398])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36197659]), 'N_1st': array([2.55708024e+11]), 'v_rad_1st': array([14.0269079])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36198967]), 'N_1st': array([2.55708024e+11]), 'v_rad_1st': array([14.0269079])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36197659]), 'N_1st': array([2.55705467e+11]), 'v_rad_1st': array([14.0269079])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36197659]), 'N_1st': array([2.55708024e+11]), 'v_rad_1st': array([14.02704817])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.37986075]), 'N_1st': array([7.5147818e+10]), 'v_rad_1st': array([14.00869711])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.37987372]), 'N_1st': array([7.5147818e+10]), 'v_rad_1st': array([14.00869711])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.37986075]), 'N_1st': array([7.51485695e+10]), 'v_rad_1st': array([14.00869711])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.37986075]), 'N_1st': array([7.5147818e+10]), 'v_rad_1st': array([14.0088372])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.37342085]), 'N_1st': array([7.12277603e+09]), 'v_rad_1st': array([13.99190913])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.37343386]), 'N_1st': array([7.12277603e+09]), 'v_rad_1st': array([13.99190913])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.37342085]), 'N_1st': array([7.1227048e+09]), 'v_rad_1st': array([13.99190913])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.37342085]), 'N_1st': array([7.12277603e+09]), 'v_rad_1st': array([13.99204904])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.42503741]), 'N_1st': array([9.36001555e+08]), 'v_rad_1st': array([13.76317956])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.42505009]), 'N_1st': array([9.36001555e+08]), 'v_rad_1st': array([13.76317956])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.42503741]), 'N_1st': array([9.36010915e+08]), 'v_rad_1st': array([13.76317956])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.42503741]), 'N_1st': array([9.36001555e+08]), 'v_rad_1st': array([13.76331719])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.49902009]), 'N_1st': array([3.43766466e+08]), 'v_rad_1st': array([13.27999701])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.49903228]), 'N_1st': array([3.43766466e+08]), 'v_rad_1st': array([13.27999701])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.49902009]), 'N_1st': array([3.43763028e+08]), 'v_rad_1st': array([13.27999701])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.49902009]), 'N_1st': array([3.43766466e+08]), 'v_rad_1st': array([13.28012981])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.42332648]), 'N_1st': array([48524023.38886697]), 'v_rad_1st': array([12.79777156])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.42333917]), 'N_1st': array([48524023.38886697]), 'v_rad_1st': array([12.79777156])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.42332648]), 'N_1st': array([48523538.14862309]), 'v_rad_1st': array([12.79777156])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.42332648]), 'N_1st': array([48524023.38886697]), 'v_rad_1st': array([12.79789954])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.2601319]), 'N_1st': array([3.49834174e+08]), 'v_rad_1st': array([12.42372586])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.26014554]), 'N_1st': array([3.49834174e+08]), 'v_rad_1st': array([12.42372586])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.2601319]), 'N_1st': array([3.49830675e+08]), 'v_rad_1st': array([12.42372586])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.2601319]), 'N_1st': array([3.49834174e+08]), 'v_rad_1st': array([12.4238501])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.12304045]), 'N_1st': array([4.43466457e+08]), 'v_rad_1st': array([11.45225094])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.12305472]), 'N_1st': array([4.43466457e+08]), 'v_rad_1st': array([11.45225094])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.12304045]), 'N_1st': array([4.43462022e+08]), 'v_rad_1st': array([11.45225094])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.12304045]), 'N_1st': array([4.43466457e+08]), 'v_rad_1st': array([11.45236546])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.44585111]), 'N_1st': array([7.21657618e+08]), 'v_rad_1st': array([10.54344822])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.95084332]), 'N_1st': array([7.02415365e+08]), 'v_rad_1st': array([10.96823171])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.95085809]), 'N_1st': array([7.02415365e+08]), 'v_rad_1st': array([10.96823171])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.95084332]), 'N_1st': array([7.02408341e+08]), 'v_rad_1st': array([10.96823171])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.95084332]), 'N_1st': array([7.02415365e+08]), 'v_rad_1st': array([10.9683414])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36817464]), 'N_1st': array([9.34230558e+08]), 'v_rad_1st': array([10.09750541])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36818768]), 'N_1st': array([9.34230558e+08]), 'v_rad_1st': array([10.09750541])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36817464]), 'N_1st': array([9.34221216e+08]), 'v_rad_1st': array([10.09750541])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.36817464]), 'N_1st': array([9.34230558e+08]), 'v_rad_1st': array([10.09760639])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.41344848]), 'N_1st': array([4.94180503e+09]), 'v_rad_1st': array([7.49326827])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.41346124]), 'N_1st': array([4.94180503e+09]), 'v_rad_1st': array([7.49326827])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.41344848]), 'N_1st': array([4.94175561e+09]), 'v_rad_1st': array([7.49326827])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.41344848]), 'N_1st': array([4.94180503e+09]), 'v_rad_1st': array([7.4933432])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.76343811]), 'N_1st': array([3.52619661e+11]), 'v_rad_1st': array([2.38157718])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.53516139]), 'N_1st': array([3.52077136e+11]), 'v_rad_1st': array([5.67800076])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.53517333]), 'N_1st': array([3.52077136e+11]), 'v_rad_1st': array([5.67800076])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.53516139]), 'N_1st': array([3.52073615e+11]), 'v_rad_1st': array([5.67800076])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.53516139]), 'N_1st': array([3.52077136e+11]), 'v_rad_1st': array([5.67805754])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.4299743]), 'N_1st': array([3.23325617e+11]), 'v_rad_1st': array([6.90505962])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.42997846]), 'N_1st': array([3.23325617e+11]), 'v_rad_1st': array([6.90505962])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.4299743]), 'N_1st': array([3.23322383e+11]), 'v_rad_1st': array([6.90505962])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.4299743]), 'N_1st': array([3.23325617e+11]), 'v_rad_1st': array([6.90512868])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.54956608]), 'N_1st': array([5.38351751e+11]), 'v_rad_1st': array([6.79862988])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.54957991]), 'N_1st': array([5.38351751e+11]), 'v_rad_1st': array([6.79862988])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.54956608]), 'N_1st': array([5.38346367e+11]), 'v_rad_1st': array([6.79862988])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.54956608]), 'N_1st': array([5.38351751e+11]), 'v_rad_1st': array([6.79869787])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.9881708]), 'N_1st': array([1.10854251e+12]), 'v_rad_1st': array([6.91194169])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.98818549]), 'N_1st': array([1.10854251e+12]), 'v_rad_1st': array([6.91194169])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.9881708]), 'N_1st': array([1.10853142e+12]), 'v_rad_1st': array([6.91194169])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.9881708]), 'N_1st': array([1.10854251e+12]), 'v_rad_1st': array([6.9120108])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.71268337]), 'N_1st': array([1.82190958e+12]), 'v_rad_1st': array([6.86261794])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.84530273]), 'N_1st': array([1.47622399e+12]), 'v_rad_1st': array([6.86191714])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.84531759]), 'N_1st': array([1.47622399e+12]), 'v_rad_1st': array([6.86191714])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.84530273]), 'N_1st': array([1.47620923e+12]), 'v_rad_1st': array([6.86191714])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.84530273]), 'N_1st': array([1.47622399e+12]), 'v_rad_1st': array([6.86198576])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.8296152]), 'N_1st': array([1.86973686e+12]), 'v_rad_1st': array([6.86821889])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.82963006]), 'N_1st': array([1.86973686e+12]), 'v_rad_1st': array([6.86821889])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.8296152]), 'N_1st': array([1.86971816e+12]), 'v_rad_1st': array([6.86821889])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.8296152]), 'N_1st': array([1.86973686e+12]), 'v_rad_1st': array([6.86828758])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.76227821]), 'N_1st': array([2.51589069e+12]), 'v_rad_1st': array([6.85592239])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79171855]), 'N_1st': array([2.2421721e+12]), 'v_rad_1st': array([6.8604432])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.7917334]), 'N_1st': array([2.2421721e+12]), 'v_rad_1st': array([6.8604432])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79171855]), 'N_1st': array([2.24214968e+12]), 'v_rad_1st': array([6.8604432])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79171855]), 'N_1st': array([2.2421721e+12]), 'v_rad_1st': array([6.86051181])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.8351098]), 'N_1st': array([1.87002015e+12]), 'v_rad_1st': array([6.87089589])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.81986866]), 'N_1st': array([2.08171643e+12]), 'v_rad_1st': array([6.86996867])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.81363781]), 'N_1st': array([2.16816943e+12]), 'v_rad_1st': array([6.86958296])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.81034402]), 'N_1st': array([2.21210926e+12]), 'v_rad_1st': array([6.86936839])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.8071841]), 'N_1st': array([2.23807312e+12]), 'v_rad_1st': array([6.86906877])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79899454]), 'N_1st': array([2.24230733e+12]), 'v_rad_1st': array([6.86732688])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79900939]), 'N_1st': array([2.24230733e+12]), 'v_rad_1st': array([6.86732688])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79899454]), 'N_1st': array([2.24228491e+12]), 'v_rad_1st': array([6.86732688])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79899454]), 'N_1st': array([2.24230733e+12]), 'v_rad_1st': array([6.86739555])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79537789]), 'N_1st': array([2.24263899e+12]), 'v_rad_1st': array([6.86600221])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79539274]), 'N_1st': array([2.24263899e+12]), 'v_rad_1st': array([6.86600221])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79537789]), 'N_1st': array([2.24261657e+12]), 'v_rad_1st': array([6.86600221])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79537789]), 'N_1st': array([2.24263899e+12]), 'v_rad_1st': array([6.86607087])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.78947554]), 'N_1st': array([2.24758897e+12]), 'v_rad_1st': array([6.86521672])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79403719]), 'N_1st': array([2.24278516e+12]), 'v_rad_1st': array([6.86570485])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79496221]), 'N_1st': array([2.24267292e+12]), 'v_rad_1st': array([6.86587748])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79497706]), 'N_1st': array([2.24267292e+12]), 'v_rad_1st': array([6.86587748])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79496221]), 'N_1st': array([2.2426505e+12]), 'v_rad_1st': array([6.86587748])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79496221]), 'N_1st': array([2.24267292e+12]), 'v_rad_1st': array([6.86594613])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79584286]), 'N_1st': array([2.24272829e+12]), 'v_rad_1st': array([6.86648108])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79518731]), 'N_1st': array([2.24268714e+12]), 'v_rad_1st': array([6.86610757])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.7950331]), 'N_1st': array([2.2426774e+12]), 'v_rad_1st': array([6.86595826])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79498768]), 'N_1st': array([2.24267453e+12]), 'v_rad_1st': array([6.86590749])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79500253]), 'N_1st': array([2.24267453e+12]), 'v_rad_1st': array([6.86590749])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79498768]), 'N_1st': array([2.2426521e+12]), 'v_rad_1st': array([6.86590749])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79498768]), 'N_1st': array([2.24267453e+12]), 'v_rad_1st': array([6.86597615])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.7949748]), 'N_1st': array([2.24267551e+12]), 'v_rad_1st': array([6.86590307])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79498965]), 'N_1st': array([2.24267551e+12]), 'v_rad_1st': array([6.86590307])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.7949748]), 'N_1st': array([2.24265308e+12]), 'v_rad_1st': array([6.86590307])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.7949748]), 'N_1st': array([2.24267551e+12]), 'v_rad_1st': array([6.86597173])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79494908]), 'N_1st': array([2.24267746e+12]), 'v_rad_1st': array([6.86589439])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79496899]), 'N_1st': array([2.24267594e+12]), 'v_rad_1st': array([6.86590109])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79497347]), 'N_1st': array([2.24267561e+12]), 'v_rad_1st': array([6.86590262])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79497447]), 'N_1st': array([2.24267553e+12]), 'v_rad_1st': array([6.86590296])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79497468]), 'N_1st': array([2.24267551e+12]), 'v_rad_1st': array([6.86590303])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79498953]), 'N_1st': array([2.24267551e+12]), 'v_rad_1st': array([6.86590303])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79497468]), 'N_1st': array([2.24265309e+12]), 'v_rad_1st': array([6.86590303])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79497468]), 'N_1st': array([2.24267551e+12]), 'v_rad_1st': array([6.86597169])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79497445]), 'N_1st': array([2.24267553e+12]), 'v_rad_1st': array([6.86590295])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79497468]), 'N_1st': array([2.24267551e+12]), 'v_rad_1st': array([6.86590303])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.79497468]), 'N_1st': array([2.24267551e+12]), 'v_rad_1st': array([6.86590303])}
# Name              Value      Min      Max   Stderr     Vary     Expr Brute_Step
# N_0_0          2.243e+12        0      inf 2.088e+11     True     None     None
# b_0_0             0.795      0.2      5.5  0.01621     True     None     None
# f_0_0            0.3331     -inf      inf        0    False     None     None
# gamma_0_0      3.74e+07     -inf      inf        0    False     None     None
# knot_y_0          1.001        0      inf        0    False     None     None
# knot_y_1         0.9999        0      inf        0    False     None     None
# knot_y_2          1.009        0      inf        0    False     None     None
# knot_y_3         0.9699        0      inf        0    False     None     None
# knot_y_4         0.9945        0      inf        0    False     None     None
# knot_y_5          1.002        0      inf        0    False     None     None
# knot_y_6         0.9999        0      inf        0    False     None     None
# lambda_0_0         7699     -inf      inf        0    False     None     None
# n_component_0         1     -inf      inf        0    False     None     None
# n_species             1     -inf      inf        0    False     None     None
# n_step               25     -inf      inf        0    False     None     None
# n_trans_0             1     -inf      inf        0    False     None     None
# v_rad_0_0         6.866     -inf      inf 0.007654     True     None     None
# v_resolution          3     -inf      inf        0    False     None     None
# chi-square value  111.61752474899386
# reduced chi-square value  2.9373032828682595
# FITTING RESULT : True
#
# Fit success:        True
# Chi square:         111.6175
# Reduced chi square: 2.9373
# Std of residuals:   0.00648

# %%
params = fitresult.params

print(f'Star: {star_name}')
print('=' * 40)
for i, mol in enumerate(molecules):
    print(f'\nSpecies {i+1}: {mol}')
    comp_idx = 0
    while f'b_{i}_{comp_idx}' in params:
        b = params[f'b_{i}_{comp_idx}']
        N = params[f'N_{i}_{comp_idx}']
        v = params[f'v_rad_{i}_{comp_idx}']
        print(f'  Component {comp_idx+1}:')
        for p, label in [(b, 'b    '), (N, 'N    '), (v, 'v_rad')]:
            if p.stderr is None:
                print(f'    {label}: {p.value:.4g}  (fixed or tied)')
            else:
                pct = abs(p.stderr / p.value) * 100 if p.value != 0 else 0
                print(f'    {label}: {p.value:.4g} +/- {p.stderr:.4g}  ({pct:.2f}%)')
        comp_idx += 1

print(f'\nChi square:         {fitresult.chisqr:.4f}')
print(f'Reduced chi square: {fitresult.redchi:.4f}')
# Out:
# Star: HD 24398
# ========================================
#
# Species 1: K_7699
#   Component 1:
#     b    : 0.795 +/- 0.01621  (2.04%)
#     N    : 2.243e+12 +/- 2.088e+11  (9.31%)
#     v_rad: 6.866 +/- 0.007654  (0.11%)
#
# Chi square:         111.6175
# Reduced chi square: 2.9373

# %%
# Top: data + continuum + total fit. Bottom: normalized flux + absorption model.
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True,
                         gridspec_kw={'height_ratios': [2, 1, 1]})

wave_list = transformations.rv_to_wavelength(np.array(species_params[0]['v_rad']), target_wave)

for i, mol in enumerate(molecules):
    p = species_params[i]
ax_top = axes[0]
ax_top.plot(wave_fit, flux_fit, color='black', lw=1, label='co added data')
ax_top.plot(wave_fit, continuum, color='red', lw=1.2, label='fitted continuum')
ax_top.plot(wave_fit, fitresult.best_fit, color='green', lw=1.2,
            label=f'total fit (continuum x absorption) — {len(p["b"])} component(s)')
ax_top.axvspan(*absorption_range, color='red', alpha=0.1)
ax_top.set_ylabel('Flux')
ax_top.set_title(f'{star_name} fit result of individual spectrum (order 0)')
ax_top.legend(loc='best')
ax_top.vlines(wave_list, flux_fit.min(), flux_fit.max(), colors='purple', linestyles='--', label='v_rad positions')

ax_bot = axes[1]
ax_bot.plot(wave_fit, normalized_flux, color='black', lw=1, label='normalized flux')
ax_bot.plot(wave_fit, fitresult.best_fit / continuum, color='green', lw=1.2,
            label='absorption model')
ax_bot.axhline(1.0, color='gray', lw=0.8, linestyle=':')
ax_bot.axvspan(*absorption_range, color='red', alpha=0.1)
ax_bot.set_ylabel('Normalized flux')
ax_bot.legend()

ax_bot = axes[2]
ax_bot.plot(wave_fit, flux_fit - fitresult.best_fit, color='black', lw=1, label='residual (data minus fit)')
ax_bot.axhline(0, color='red', lw=0.8)
ax_bot.fill_between(wave_fit, -residual_std, residual_std, color='gray', alpha=0.3,
                 label=f'+/- 1 sigma ({residual_std:.4f})')
ax_bot.set_xlabel('Wavelength (Å)')
ax_bot.set_ylabel('Residual (data minus fit)')
ax_bot.legend(loc='lower left')


plt.tight_layout()
plt.savefig(r"C:\Users\User\Downloads\PYTHON PROJECTS\edibles\edibles\projects\GUI\KI_fits_self\results\plots\HD_24398_order_0.png")
plt.show()

# %%
# Residuals: data minus total fit. Should look like noise centered on zero.
plt.figure(figsize=(10, 3))
plt.plot(wave_fit, flux_fit - fitresult.best_fit, color='black', lw=1)
plt.axhline(0, color='red', lw=0.8)
plt.fill_between(wave_fit, -residual_std, residual_std, color='gray', alpha=0.3,
                 label=f'+/- 1 sigma ({residual_std:.4f})')
plt.xlabel('Wavelength (A)')
plt.ylabel('Residual (data minus fit)')
plt.title('Residuals')
plt.legend()
plt.show()

# %%
fitresult.fit_report()
with open(r"C:\Users\User\Downloads\PYTHON PROJECTS\edibles\edibles\projects\GUI\KI_fits_self\results\HD 24398_order0_params.txt", 'w') as f:
 f.write(fitresult.fit_report())
