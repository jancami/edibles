# %%
# The usual suspects
import numpy as np
import matplotlib.pyplot as plt

# The EDIBLES bits that find files and load spectra
from edibles.utils.edibles_oracle import EdiblesOracle
from edibles.utils.edibles_spectrum import EdiblesSpectrum

import sys
import os

gui_path = os.path.abspath(os.path.join(os.getcwd(), '..'))

if gui_path not in sys.path:
 sys.path.insert(0, gui_path)

# Our project's own helpers (these live in the same folder as this notebook)
from flux_wave_find import wave_flux_data
from co_adding_flux import coadd_spectra
from main_run import get_species_data, astrovoigtfit_run
from main import master_function
from edibles.projects.edr5_integration import transformations

# Make the plots a bit less ugly
plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['figure.dpi'] = 100
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.3

print('All imports happy. Onward.')
# Out:
# All imports happy. Onward.

# %%
star_name = 'HD 27778'
target_wave = 7698.965         # rest wavelength of the K_7699 line
wrange = [7697.0, 7700.0]       # window around the line for loading data

# Show every species the code already knows about
all_species = get_species_data('species.txt')
print('Species I know about:')
for name, info in all_species.items():
    print(f"  {name:20s} line={info['line']}  wrange={info['wrange']}")
# Out:
# Species I know about:
#   K_4044               line=4044.142  wrange=[4043.0, 4045.0]
#   K_7699               line=7698.965  wrange=[7697.0, 7700.0]
#   12CH+_4032           line=4232.548  wrange=[4231.5, 4233.5]
#   13CH+_4032           line=4232.548  wrange=[4231.5, 4233.5]
#   7Li_6707             line=6707.761  wrange=[6707.1, 6708.2]
#   6Li_6707             line=6707.761  wrange=[6707.1, 6708.2]
#   Na_D_5892            line=5889.951  wrange=[5889.0, 5897.0]
#   85Rb_7800            line=7800.250  wrange=[7798.0, 7800.9]
#   87Rb_7800            line=7800.250  wrange=[7798.0, 7800.9]

# %%
oracle = EdiblesOracle()
files = oracle.getFilteredObsList([star_name], Wave=target_wave, MergedOnly=False)

# Turn it into a plain list so we can index it like normal humans
if hasattr(files, 'tolist'):
    files = files.tolist()

print(f'Found {len(files)} files covering {target_wave} A for {star_name}:\n')
for i, f in enumerate(files):
    print(f'  [{i}]  {f}')
# Out:
# ***Common Objects***
# ['HD 27778']
# **Filtered File List**
# 23753    orders/HD27778_2014-11-16T05:40:12_860nm_redl_...
# 23784    combined/HD27778_2014-11-16T05:05:27_860nm_red...
# 23786    orders/HD27778_2014-11-16T05:05:27_860nm_redl_...
# 23871    combined/HD27778_2014-11-16T05:40:12_860nm_red...
# Name: Filename, dtype: str
# 4
# Found 4 files covering 7698.965 A for HD 27778:
#
#   [0]  orders/HD27778_2014-11-16T05:40:12_860nm_redl_O13.fits
#   [1]  combined/HD27778_2014-11-16T05:05:27_860nm_redl.fits
#   [2]  orders/HD27778_2014-11-16T05:05:27_860nm_redl_O13.fits
#   [3]  combined/HD27778_2014-11-16T05:40:12_860nm_redl.fits

# %%
# Pick the indices of the files you want to co add (edit this list)
selected_indices = [0, 2]

# Pull each spectrum from disk (just the wavelength window, median normalized)
wave_list = []
flux_list = []

for i in selected_indices:
    fname = files[i]
    w, f = wave_flux_data(star_name=star_name, wave=target_wave,
                          wrange=wrange, file_name=fname)
    if w is None or len(w) == 0:
        print(f'Skipping file {i}: no data in range')
        continue
    wave_list.append(w)
    flux_list.append(f)
    print(f'Loaded file {i}: {len(w)} points')

# Quick look so you can spot weirdos
plt.figure()
for i, (w, f) in enumerate(zip(wave_list, flux_list)):
    plt.plot(w, f, alpha=0.6, label=f'file {selected_indices[i]}')
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux (median normalized)')
plt.title(f'Individual spectra for {star_name}')
plt.legend()
plt.show()
# Out:
# Loaded file 0: 87 points
# Loaded file 2: 87 points

# %%
sigma_per_spectrum = 0.002   # noise estimate per individual spectrum

wave_coadd, flux_coadd, sigma_coadd = coadd_spectra(
    wave_list, flux_list, sigma_list=sigma_per_spectrum,
)

print(f'Co added spectrum: {len(wave_coadd)} points')
print(f'Estimated noise of the co added flux: {sigma_coadd}')

plt.figure()
for w, f in zip(wave_list, flux_list):
    plt.plot(w, f, alpha=0.25, lw=0.8)
plt.plot(wave_coadd, flux_coadd, color='black', lw=1.2, label='co added')
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux')
plt.title('Co added spectrum (thin lines are the originals)')
plt.legend()
plt.show()
# Out:
# Co added spectrum: 87 points
# Estimated noise of the co added flux: 0.001414213562373095

# %%
fit_range = (7698.6, 7700)
absorption_range = (7699.2, 7699.54)

plt.figure()
plt.plot(wave_coadd, flux_coadd, color='black', lw=1)
plt.axvspan(*fit_range, color='blue', alpha=0.1, label='fit range')
plt.axvspan(*absorption_range, color='red', alpha=0.2, label='absorption range')
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux')
plt.title('Sanity check: are your ranges in the right place?')
plt.legend()
plt.show()

# Crop the data to the fit range so we hand only the relevant chunk to the fitter
mask = (wave_coadd >= fit_range[0]) & (wave_coadd <= fit_range[1])
wave_fit = wave_coadd[mask]
flux_fit = flux_coadd[mask]
print(f'After cropping to fit range: {len(wave_fit)} points')
# Out:
# After cropping to fit range: 41 points

# %%
molecules = ['K_7699'] #this should match with the first column of species.txt

species_params = {
    0: {
        'b':     [3],
        'N':     [1e12],
        'v_rad': [15.3],
    } #,   # uncomment if you have  second species
    # 1: {
    #     'b':     [2.0, 2.0],
    #     'N':     [1e12, 1e12],
    #     'v_rad': [5,5],
    # }
}

 

print(f"You're fitting {len(molecules)} species with these components:")
for i, mol in enumerate(molecules):
    p = species_params[i]
    print(f"  {mol}: {len(p['b'])} component(s)")
    print(f"    b     = {p['b']}")
    print(f"    N     = {p['N']}")
    print(f"    v_rad = {p['v_rad']}")
# Out:
# You're fitting 1 species with these components:
#   K_7699: 1 component(s)
#     b     = [3]
#     N     = [1000000000000.0]
#     v_rad = [15.3]

# %%
# Flavor A: auto, equidistant knots, just say how many
n_knots = 10
# knots_x_array = None

# Flavor B: manual, you say exactly where every knot goes
# Uncomment the next line to use manual mode (it overrides n_knots)
knots_x_array = [7698.6, 7698.8, 7699, 7699.16, 7699.6, 7699.68, 7699.77, 7699.9, 7700]

spline_order = 1   # 1 linear, 2 quadratic, 3 cubic

# Preview where the knots would land
if knots_x_array is None:
    preview_knots = np.linspace(fit_range[0], fit_range[1], n_knots)
    inside_abs = (preview_knots >= absorption_range[0]) & (preview_knots <= absorption_range[1])
    preview_knots = preview_knots[~inside_abs]
    preview_knots = np.sort(np.unique(np.append(
        preview_knots, [absorption_range[0] - 0.05, absorption_range[1] + 0.05])))
    knot_label = f'{len(preview_knots)} auto knots (fitter may tweak)'
else:
    preview_knots = np.asarray(knots_x_array)
    knot_label = f'{len(preview_knots)} manual knots'

plt.figure()
plt.plot(wave_fit, flux_fit, color='black', lw=1)
plt.axvspan(*absorption_range, color='red', alpha=0.2, label='absorption range')
plt.vlines(preview_knots, flux_fit.min(), flux_fit.max(),
           colors='orange', linestyles=':', label=knot_label)
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux')
plt.title('Knot preview')
plt.legend()
plt.show()

# %%
fit_std_dev = 0.004 # standard dev of the co-added spectra 
# this is a very important parameter... ideally you should find 
# this by taking a wavelength region from the spectra where the continuum
# is pretty flatt with almost no absorption and fitting it 
# with a line and find the stardard dev of the data points 

fitresult, normalized_flux, continuum, residual_std = astrovoigtfit_run(
    wave_fit, flux_fit, molecules, species_params,
    absorption_range, n_knots=n_knots, knots_x_array=knots_x_array,
    species_file='species.txt', spline_order=spline_order,
    std_dev=fit_std_dev,
)

print(f'\nFit success:        {fitresult.success}')
print(f'Chi square:         {fitresult.chisqr:.4f}')
print(f'Reduced chi square: {fitresult.redchi:.4f}')
print(f'Std of residuals:   {residual_std:.5f}')
# Out:
# Species: K_7699, Lambda: [7698.965], f: [0.3331], Gamma: [37400000.0]
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.]), 'N_1st': array([1.e+12]), 'v_rad_1st': array([15.3])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.]), 'N_1st': array([1.e+12]), 'v_rad_1st': array([15.3])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.]), 'N_1st': array([1.e+12]), 'v_rad_1st': array([15.3])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.]), 'N_1st': array([1.e+12]), 'v_rad_1st': array([15.3])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.0000015]), 'N_1st': array([1.e+12]), 'v_rad_1st': array([15.3])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.]), 'N_1st': array([1.00001e+12]), 'v_rad_1st': array([15.3])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.]), 'N_1st': array([1.e+12]), 'v_rad_1st': array([15.300153])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.64152771]), 'N_1st': array([6.45542682e+11]), 'v_rad_1st': array([15.29939102])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.64153538]), 'N_1st': array([6.45542682e+11]), 'v_rad_1st': array([15.29939102])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.64152771]), 'N_1st': array([6.45536227e+11]), 'v_rad_1st': array([15.29939102])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.64152771]), 'N_1st': array([6.45542682e+11]), 'v_rad_1st': array([15.29954401])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.01919897]), 'N_1st': array([1.85967972e+11]), 'v_rad_1st': array([15.2959992])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.01920984]), 'N_1st': array([1.85967972e+11]), 'v_rad_1st': array([15.2959992])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.01919897]), 'N_1st': array([1.85969832e+11]), 'v_rad_1st': array([15.2959992])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.01919897]), 'N_1st': array([1.85967972e+11]), 'v_rad_1st': array([15.29615216])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.2574794]), 'N_1st': array([1.08097324e+10]), 'v_rad_1st': array([15.27469306])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.25749197]), 'N_1st': array([1.08097324e+10]), 'v_rad_1st': array([15.27469306])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.2574794]), 'N_1st': array([1.08096243e+10]), 'v_rad_1st': array([15.27469306])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.2574794]), 'N_1st': array([1.08097324e+10]), 'v_rad_1st': array([15.27484581])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.49959541]), 'N_1st': array([1.26546995e+09]), 'v_rad_1st': array([14.94309191])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.49959613]), 'N_1st': array([1.26546995e+09]), 'v_rad_1st': array([14.94309191])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.49959541]), 'N_1st': array([1.2654573e+09]), 'v_rad_1st': array([14.94309191])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.49959541]), 'N_1st': array([1.26546995e+09]), 'v_rad_1st': array([14.94324134])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.49186216]), 'N_1st': array([5.0203361e+09]), 'v_rad_1st': array([13.050122])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.49185874]), 'N_1st': array([5.0203361e+09]), 'v_rad_1st': array([13.050122])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.49186216]), 'N_1st': array([5.02028589e+09]), 'v_rad_1st': array([13.050122])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.49186216]), 'N_1st': array([5.0203361e+09]), 'v_rad_1st': array([13.05025251])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.15092996]), 'N_1st': array([5.70668103e+10]), 'v_rad_1st': array([9.29034531])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.15094378]), 'N_1st': array([5.70668103e+10]), 'v_rad_1st': array([9.29034531])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.15092996]), 'N_1st': array([5.70662396e+10]), 'v_rad_1st': array([9.29034531])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.15092996]), 'N_1st': array([5.70668103e+10]), 'v_rad_1st': array([9.29043821])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.07928496]), 'N_1st': array([5.09968227e+11]), 'v_rad_1st': array([1.72781519])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.11200322]), 'N_1st': array([5.04350526e+11]), 'v_rad_1st': array([6.76333583])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.11201734]), 'N_1st': array([5.04350526e+11]), 'v_rad_1st': array([6.76333583])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.11200322]), 'N_1st': array([5.04345483e+11]), 'v_rad_1st': array([6.76333583])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.11200322]), 'N_1st': array([5.04350526e+11]), 'v_rad_1st': array([6.76340347])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.34588249]), 'N_1st': array([5.71377971e+11]), 'v_rad_1st': array([8.86313594])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.34589561]), 'N_1st': array([5.71377971e+11]), 'v_rad_1st': array([8.86313594])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.34588249]), 'N_1st': array([5.71372257e+11]), 'v_rad_1st': array([8.86313594])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.34588249]), 'N_1st': array([5.71377971e+11]), 'v_rad_1st': array([8.86322457])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.43587282]), 'N_1st': array([5.92617855e+11]), 'v_rad_1st': array([7.59192076])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.43587858]), 'N_1st': array([5.92617855e+11]), 'v_rad_1st': array([7.59192076])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.43587282]), 'N_1st': array([5.92611929e+11]), 'v_rad_1st': array([7.59192076])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([3.43587282]), 'N_1st': array([5.92617855e+11]), 'v_rad_1st': array([7.59199668])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.80873157]), 'N_1st': array([6.34684369e+11]), 'v_rad_1st': array([8.10554094])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.80873199]), 'N_1st': array([6.34684369e+11]), 'v_rad_1st': array([8.10554094])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.80873157]), 'N_1st': array([6.34678022e+11]), 'v_rad_1st': array([8.10554094])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.80873157]), 'N_1st': array([6.34684369e+11]), 'v_rad_1st': array([8.10562199])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.87757328]), 'N_1st': array([6.65855187e+11]), 'v_rad_1st': array([7.98540713])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.87757356]), 'N_1st': array([6.65855187e+11]), 'v_rad_1st': array([7.98540713])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.87757328]), 'N_1st': array([6.65848529e+11]), 'v_rad_1st': array([7.98540713])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.87757328]), 'N_1st': array([6.65855187e+11]), 'v_rad_1st': array([7.98548698])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.82705878]), 'N_1st': array([6.66975182e+11]), 'v_rad_1st': array([7.99072589])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.82705901]), 'N_1st': array([6.66975182e+11]), 'v_rad_1st': array([7.99072589])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.82705878]), 'N_1st': array([6.66968512e+11]), 'v_rad_1st': array([7.99072589])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.82705878]), 'N_1st': array([6.66975182e+11]), 'v_rad_1st': array([7.9908058])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.84126557]), 'N_1st': array([6.6746975e+11]), 'v_rad_1st': array([7.99006193])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.84126566]), 'N_1st': array([6.6746975e+11]), 'v_rad_1st': array([7.99006193])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.84126557]), 'N_1st': array([6.67463075e+11]), 'v_rad_1st': array([7.99006193])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.84126557]), 'N_1st': array([6.6746975e+11]), 'v_rad_1st': array([7.99014184])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83730547]), 'N_1st': array([6.6736513e+11]), 'v_rad_1st': array([7.990223])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83730559]), 'N_1st': array([6.6736513e+11]), 'v_rad_1st': array([7.990223])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83730547]), 'N_1st': array([6.67358456e+11]), 'v_rad_1st': array([7.990223])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83730547]), 'N_1st': array([6.6736513e+11]), 'v_rad_1st': array([7.99030291])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83849747]), 'N_1st': array([6.67397444e+11]), 'v_rad_1st': array([7.99017861])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83849758]), 'N_1st': array([6.67397444e+11]), 'v_rad_1st': array([7.99017861])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83849747]), 'N_1st': array([6.6739077e+11]), 'v_rad_1st': array([7.99017861])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83849747]), 'N_1st': array([6.67397444e+11]), 'v_rad_1st': array([7.99025851])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83809025]), 'N_1st': array([6.67387221e+11]), 'v_rad_1st': array([7.99019191])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83809037]), 'N_1st': array([6.67387221e+11]), 'v_rad_1st': array([7.99019191])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83809025]), 'N_1st': array([6.67380547e+11]), 'v_rad_1st': array([7.99019191])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83809025]), 'N_1st': array([6.67387221e+11]), 'v_rad_1st': array([7.99027182])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.8381326]), 'N_1st': array([6.67389395e+11]), 'v_rad_1st': array([7.99018744])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83813272]), 'N_1st': array([6.67389395e+11]), 'v_rad_1st': array([7.99018744])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.8381326]), 'N_1st': array([6.67382721e+11]), 'v_rad_1st': array([7.99018744])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.8381326]), 'N_1st': array([6.67389395e+11]), 'v_rad_1st': array([7.99026734])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.83812945]), 'N_1st': array([6.67389187e+11]), 'v_rad_1st': array([7.99018797])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.8381326]), 'N_1st': array([6.67389395e+11]), 'v_rad_1st': array([7.99018744])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.8381326]), 'N_1st': array([6.67389395e+11]), 'v_rad_1st': array([7.99018744])}
# Name              Value      Min      Max   Stderr     Vary     Expr Brute_Step
# N_0_0          6.674e+11        0      inf 2.487e+10     True     None     None
# b_0_0             2.838      0.2      5.5   0.1467     True     None     None
# f_0_0            0.3331     -inf      inf        0    False     None     None
# gamma_0_0      3.74e+07     -inf      inf        0    False     None     None
# knot_y_0              1        0      inf        0    False     None     None
# knot_y_1          1.005        0      inf        0    False     None     None
# knot_y_2          1.002        0      inf        0    False     None     None
# knot_y_3         0.9959        0      inf        0    False     None     None
# knot_y_4         0.9902        0      inf        0    False     None     None
# knot_y_5         0.9703        0      inf        0    False     None     None
# knot_y_6          0.991        0      inf        0    False     None     None
# knot_y_7         0.9966        0      inf        0    False     None     None
# knot_y_8         0.9977        0      inf        0    False     None     None
# lambda_0_0         7699     -inf      inf        0    False     None     None
# n_component_0         1     -inf      inf        0    False     None     None
# n_species             1     -inf      inf        0    False     None     None
# n_step               25     -inf      inf        0    False     None     None
# n_trans_0             1     -inf      inf        0    False     None     None
# v_rad_0_0          7.99     -inf      inf  0.04746     True     None     None
# v_resolution          3     -inf      inf        0    False     None     None
# chi-square value  1537.2213327788168
# reduced chi-square value  40.4531929678636
# FITTING RESULT : True
#
# Fit success:        True
# Chi square:         1537.2213
# Reduced chi square: 40.4532
# Std of residuals:   0.02432

# %%
params = fitresult.params

print(f'Star: {star_name}')
print('=' * 40)
for i, mol in enumerate(molecules):
    print(f'\nSpecies {i+1}: {mol}')
    comp_idx = 0
    while f'b_{i}_{comp_idx}' in params:
        b = params[f'b_{i}_{comp_idx}']
        N = params[f'N_{i}_{comp_idx}']
        v = params[f'v_rad_{i}_{comp_idx}']
        print(f'  Component {comp_idx+1}:')
        for p, label in [(b, 'b    '), (N, 'N    '), (v, 'v_rad')]:
            if p.stderr is None:
                print(f'    {label}: {p.value:.4g}  (fixed or tied)')
            else:
                pct = abs(p.stderr / p.value) * 100 if p.value != 0 else 0
                print(f'    {label}: {p.value:.4g} +/- {p.stderr:.4g}  ({pct:.2f}%)')
        comp_idx += 1

print(f'\nChi square:         {fitresult.chisqr:.4f}')
print(f'Reduced chi square: {fitresult.redchi:.4f}')
# Out:
# Star: HD 27778
# ========================================
#
# Species 1: K_7699
#   Component 1:
#     b    : 2.838 +/- 0.1467  (5.17%)
#     N    : 6.674e+11 +/- 2.487e+10  (3.73%)
#     v_rad: 7.99 +/- 0.04746  (0.59%)
#
# Chi square:         1537.2213
# Reduced chi square: 40.4532

# %%
# Top: data + continuum + total fit. Bottom: normalized flux + absorption model.
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True,
                         gridspec_kw={'height_ratios': [2, 1, 1]})


wave_list = transformations.rv_to_wavelength(np.array(species_params[0]['v_rad']), target_wave)

for i, mol in enumerate(molecules):
    p = species_params[i]
ax_top = axes[0]
ax_top.plot(wave_fit, flux_fit, color='black', lw=1, label='co added data')
ax_top.plot(wave_fit, continuum, color='red', lw=1.2, label='fitted continuum')
ax_top.plot(wave_fit, fitresult.best_fit, color='green', lw=1.2,
            label=f'total fit (continuum x absorption) — {len(p["b"])} component(s)')
ax_top.axvspan(*absorption_range, color='red', alpha=0.1)
ax_top.set_ylabel('Flux')
ax_top.set_title(f'{star_name} fit result')
ax_top.legend(loc='best')
ax_top.vlines(wave_list, flux_fit.min(), flux_fit.max(), colors='purple', linestyles='--', label='v_rad positions')

ax_bot = axes[1]
ax_bot.plot(wave_fit, normalized_flux, color='black', lw=1, label='normalized flux')
ax_bot.plot(wave_fit, fitresult.best_fit / continuum, color='green', lw=1.2,
            label='absorption model')
ax_bot.axhline(1.0, color='gray', lw=0.8, linestyle=':')
ax_bot.axvspan(*absorption_range, color='red', alpha=0.1)
ax_bot.set_ylabel('Normalized flux')
ax_bot.legend()

ax_bot = axes[2]
ax_bot.plot(wave_fit, flux_fit - fitresult.best_fit, color='black', lw=1, label='residual (data minus fit)')
ax_bot.axhline(0, color='red', lw=0.8)
ax_bot.fill_between(wave_fit, -residual_std, residual_std, color='gray', alpha=0.3,
                 label=f'+/- 1 sigma ({residual_std:.4f})')
ax_bot.set_xlabel('Wavelength (Å)')
ax_bot.set_ylabel('Residual (data minus fit)')
ax_bot.legend(loc='lower left')


plt.tight_layout()
plt.savefig(r"C:\Users\User\Downloads\PYTHON PROJECTS\edibles\edibles\projects\GUI\KI_fits_self\results\plots\HD_27778.png")
plt.show()

# %%
# Residuals: data minus total fit. Should look like noise centered on zero.
plt.figure(figsize=(10, 3))
plt.plot(wave_fit, flux_fit - fitresult.best_fit, color='black', lw=1)
plt.axhline(0, color='red', lw=0.8)
plt.fill_between(wave_fit, -residual_std, residual_std, color='gray', alpha=0.3,
                 label=f'+/- 1 sigma ({residual_std:.4f})')
plt.xlabel('Wavelength (A)')
plt.ylabel('Residual (data minus fit)')
plt.title('Residuals')
plt.legend()
plt.show()

# %%
fitresult.fit_report()
with open(r"C:\Users\User\Downloads\PYTHON PROJECTS\edibles\edibles\projects\GUI\KI_fits_self\results\HD 27778_params.txt", 'w') as f:
 f.write(fitresult.fit_report())
