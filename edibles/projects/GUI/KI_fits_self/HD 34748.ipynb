# %%
# The usual suspects
import numpy as np
import matplotlib.pyplot as plt

# The EDIBLES bits that find files and load spectra
from edibles.utils.edibles_oracle import EdiblesOracle
from edibles.utils.edibles_spectrum import EdiblesSpectrum

import sys
import os

gui_path = os.path.abspath(os.path.join(os.getcwd(), '..'))

if gui_path not in sys.path:
 sys.path.insert(0, gui_path)

# Our project's own helpers (these live in the same folder as this notebook)
from flux_wave_find import wave_flux_data
from co_adding_flux import coadd_spectra
from main_run import get_species_data, astrovoigtfit_run
from main import master_function
from edibles.projects.edr5_integration import transformations

# Make the plots a bit less ugly
plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['figure.dpi'] = 100
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.3

print('All imports happy. Onward.')
# Out:
# All imports happy. Onward.

# %%
star_name = 'HD 34748'
target_wave = 7698.965         # rest wavelength of the K_7699 line
wrange = [7697.0, 7700.0]       # window around the line for loading data

# Show every species the code already knows about
all_species = get_species_data('species.txt')
print('Species I know about:')
for name, info in all_species.items():
    print(f"  {name:20s} line={info['line']}  wrange={info['wrange']}")
# Out:
# Species I know about:
#   K_4044               line=4044.142  wrange=[4043.0, 4045.0]
#   K_7699               line=7698.965  wrange=[7697.0, 7700.0]
#   12CH+_4032           line=4232.548  wrange=[4231.5, 4233.5]
#   13CH+_4032           line=4232.548  wrange=[4231.5, 4233.5]
#   7Li_6707             line=6707.761  wrange=[6707.1, 6708.2]
#   6Li_6707             line=6707.761  wrange=[6707.1, 6708.2]
#   Na_D_5892            line=5889.951  wrange=[5889.0, 5897.0]
#   85Rb_7800            line=7800.250  wrange=[7798.0, 7800.9]
#   87Rb_7800            line=7800.250  wrange=[7798.0, 7800.9]

# %%
oracle = EdiblesOracle()
files = oracle.getFilteredObsList([star_name], Wave=target_wave, MergedOnly=False)

# Turn it into a plain list so we can index it like normal humans
if hasattr(files, 'tolist'):
    files = files.tolist()

print(f'Found {len(files)} files covering {target_wave} A for {star_name}:\n')
for i, f in enumerate(files):
    print(f'  [{i}]  {f}')
# Out:
# ***Common Objects***
# ['HD 34748']
# **Filtered File List**
# 24497    combined/HD34748_2016-08-21T08:30:15_860nm_red...
# 24604    orders/HD34748_2016-08-21T08:30:15_860nm_redl_...
# Name: Filename, dtype: str
# 2
# Found 2 files covering 7698.965 A for HD 34748:
#
#   [0]  combined/HD34748_2016-08-21T08:30:15_860nm_redl.fits
#   [1]  orders/HD34748_2016-08-21T08:30:15_860nm_redl_O13.fits

# %%
# Pick the indices of the files you want to co add (edit this list)
selected_indices = [1]

# Pull each spectrum from disk (just the wavelength window, median normalized)
wave_list = []
flux_list = []

for i in selected_indices:
    fname = files[i]
    w, f = wave_flux_data(star_name=star_name, wave=target_wave,
                          wrange=wrange, file_name=fname)
    if w is None or len(w) == 0:
        print(f'Skipping file {i}: no data in range')
        continue
    wave_list.append(w)
    flux_list.append(f)
    print(f'Loaded file {i}: {len(w)} points')

# Quick look so you can spot weirdos
plt.figure()
for i, (w, f) in enumerate(zip(wave_list, flux_list)):
    plt.plot(w, f, alpha=0.6, label=f'file {selected_indices[i]}')
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux (median normalized)')
plt.title(f'Individual spectra for {star_name}')
plt.legend()
plt.show()
# Out:
# Loaded file 1: 87 points

# %%
sigma_per_spectrum = 0.002   # noise estimate per individual spectrum

wave_coadd, flux_coadd, sigma_coadd = coadd_spectra(
    wave_list, flux_list, sigma_list=sigma_per_spectrum,
)

print(f'Co added spectrum: {len(wave_coadd)} points')
print(f'Estimated noise of the co added flux: {sigma_coadd}')

plt.figure()
for w, f in zip(wave_list, flux_list):
    plt.plot(w, f, alpha=0.25, lw=0.8)
plt.plot(wave_coadd, flux_coadd, color='black', lw=1.2, label='co added')
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux')
plt.title('Co added spectrum (thin lines are the originals)')
plt.legend()
plt.show()
# Out:
# Co added spectrum: 87 points
# Estimated noise of the co added flux: 0.002

# %%
fit_range = (7698.4, 7699.5)
absorption_range = (7698.75, 7699.3)

plt.figure()
plt.plot(wave_coadd, flux_coadd, color='black', lw=1)
plt.axvspan(*fit_range, color='blue', alpha=0.1, label='fit range')
plt.axvspan(*absorption_range, color='red', alpha=0.2, label='absorption range')
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux')
plt.title('Sanity check: are your ranges in the right place?')
plt.legend()
plt.show()

# Crop the data to the fit range so we hand only the relevant chunk to the fitter
mask = (wave_coadd >= fit_range[0]) & (wave_coadd <= fit_range[1])
wave_fit = wave_coadd[mask]
flux_fit = flux_coadd[mask]
print(f'After cropping to fit range: {len(wave_fit)} points')
# Out:
# After cropping to fit range: 32 points

# %%
molecules = ['K_7699'] #this should match with the first column of species.txt

species_params = {
    0: {
        'b':     [2, 1],
        'N':     [5e10, 1e11],
        'v_rad': [-1, 5],
    } #,   # uncomment if you have  second species
    # 1: {
    #     'b':     [2.0, 2.0],
    #     'N':     [1e12, 1e12],
    #     'v_rad': [5,5],
    # }
}

 

print(f"You're fitting {len(molecules)} species with these components:")
for i, mol in enumerate(molecules):
    p = species_params[i]
    print(f"  {mol}: {len(p['b'])} component(s)")
    print(f"    b     = {p['b']}")
    print(f"    N     = {p['N']}")
    print(f"    v_rad = {p['v_rad']}")
# Out:
# You're fitting 1 species with these components:
#   K_7699: 2 component(s)
#     b     = [2, 1]
#     N     = [50000000000.0, 100000000000.0]
#     v_rad = [-1, 5]

# %%
# Flavor A: auto, equidistant knots, just say how many
n_knots = 10
# knots_x_array = None

# Flavor B: manual, you say exactly where every knot goes
# Uncomment the next line to use manual mode (it overrides n_knots)
knots_x_array = [7698.4, 7698.5, 7698.6, 7698.7, 7699.35, 7699.4, 7699.5]

spline_order = 1   # 1 linear, 2 quadratic, 3 cubic

# Preview where the knots would land
if knots_x_array is None:
    preview_knots = np.linspace(fit_range[0], fit_range[1], n_knots)
    inside_abs = (preview_knots >= absorption_range[0]) & (preview_knots <= absorption_range[1])
    preview_knots = preview_knots[~inside_abs]
    preview_knots = np.sort(np.unique(np.append(
        preview_knots, [absorption_range[0] - 0.05, absorption_range[1] + 0.05])))
    knot_label = f'{len(preview_knots)} auto knots (fitter may tweak)'
else:
    preview_knots = np.asarray(knots_x_array)
    knot_label = f'{len(preview_knots)} manual knots'

plt.figure()
plt.plot(wave_fit, flux_fit, color='black', lw=1)
plt.axvspan(*absorption_range, color='red', alpha=0.2, label='absorption range')
plt.vlines(preview_knots, flux_fit.min(), flux_fit.max(),
           colors='orange', linestyles=':', label=knot_label)
plt.xlabel('Wavelength (A)')
plt.ylabel('Flux')
plt.title('Knot preview')
plt.legend()
plt.show()

# %%
fit_std_dev = 0.004 # standard dev of the co-added spectra 
# this is a very important parameter... ideally you should find 
# this by taking a wavelength region from the spectra where the continuum
# is pretty flatt with almost no absorption and fitting it 
# with a line and find the stardard dev of the data points 

fitresult, normalized_flux, continuum, residual_std = astrovoigtfit_run(
    wave_fit, flux_fit, molecules, species_params,
    absorption_range, n_knots=n_knots, knots_x_array=knots_x_array,
    species_file='species.txt', spline_order=spline_order,
    std_dev=fit_std_dev,
)

print(f'\nFit success:        {fitresult.success}')
print(f'Chi square:         {fitresult.chisqr:.4f}')
print(f'Reduced chi square: {fitresult.redchi:.4f}')
print(f'Std of residuals:   {residual_std:.5f}')
# Out:
# Species: K_7699, Lambda: [7698.965], f: [0.3331], Gamma: [37400000.0]
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2., 1.]), 'N_1st': array([5.e+10, 1.e+11]), 'v_rad_1st': array([-1.,  5.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2., 1.]), 'N_1st': array([5.e+10, 1.e+11]), 'v_rad_1st': array([-1.,  5.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2., 1.]), 'N_1st': array([5.e+10, 1.e+11]), 'v_rad_1st': array([-1.,  5.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2., 1.]), 'N_1st': array([5.e+10, 1.e+11]), 'v_rad_1st': array([-1.,  5.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.0000082, 1.       ]), 'N_1st': array([5.e+10, 1.e+11]), 'v_rad_1st': array([-1.,  5.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2., 1.]), 'N_1st': array([5.00005e+10, 1.00000e+11]), 'v_rad_1st': array([-1.,  5.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2., 1.]), 'N_1st': array([5.e+10, 1.e+11]), 'v_rad_1st': array([-0.99999,  5.     ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.        , 1.00001466]), 'N_1st': array([5.e+10, 1.e+11]), 'v_rad_1st': array([-1.,  5.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2., 1.]), 'N_1st': array([5.00000e+10, 1.00001e+11]), 'v_rad_1st': array([-1.,  5.])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2., 1.]), 'N_1st': array([5.e+10, 1.e+11]), 'v_rad_1st': array([-1.     ,  5.00005])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.35153256, 2.74241044]), 'N_1st': array([2.69188629e+10, 8.70077976e+10]), 'v_rad_1st': array([-0.4138864 ,  4.20353061])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.35154335, 2.74241044]), 'N_1st': array([2.69188629e+10, 8.70077976e+10]), 'v_rad_1st': array([-0.4138864 ,  4.20353061])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.35153256, 2.74241044]), 'N_1st': array([2.69191321e+10, 8.70077976e+10]), 'v_rad_1st': array([-0.4138864 ,  4.20353061])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.35153256, 2.74241044]), 'N_1st': array([2.69188629e+10, 8.70077976e+10]), 'v_rad_1st': array([-0.41388227,  4.20353061])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.35153256, 2.74241151]), 'N_1st': array([2.69188629e+10, 8.70077976e+10]), 'v_rad_1st': array([-0.4138864 ,  4.20353061])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.35153256, 2.74241044]), 'N_1st': array([2.69188629e+10, 8.70086676e+10]), 'v_rad_1st': array([-0.4138864 ,  4.20353061])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.35153256, 2.74241044]), 'N_1st': array([2.69188629e+10, 8.70077976e+10]), 'v_rad_1st': array([-0.4138864 ,  4.20357264])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.45404315, 1.67071082]), 'N_1st': array([7.59415749e+09, 1.38388645e+11]), 'v_rad_1st': array([-1.66230102,  2.63579816])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.17394307, 2.03649618]), 'N_1st': array([3.14347548e+10, 1.25437146e+11]), 'v_rad_1st': array([-0.28134016,  3.21401953])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.17395669, 2.03649618]), 'N_1st': array([3.14347548e+10, 1.25437146e+11]), 'v_rad_1st': array([-0.28134016,  3.21401953])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.17394307, 2.03649618]), 'N_1st': array([3.14350691e+10, 1.25437146e+11]), 'v_rad_1st': array([-0.28134016,  3.21401953])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.17394307, 2.03649618]), 'N_1st': array([3.14347548e+10, 1.25437146e+11]), 'v_rad_1st': array([-0.28133735,  3.21401953])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.17394307, 2.03650405]), 'N_1st': array([3.14347548e+10, 1.25437146e+11]), 'v_rad_1st': array([-0.28134016,  3.21401953])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.17394307, 2.03649618]), 'N_1st': array([3.14347548e+10, 1.25438400e+11]), 'v_rad_1st': array([-0.28134016,  3.21401953])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.17394307, 2.03649618]), 'N_1st': array([3.14347548e+10, 1.25437146e+11]), 'v_rad_1st': array([-0.28134016,  3.21405167])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.26864216, 1.10458394]), 'N_1st': array([4.94916723e+10, 1.16620900e+11]), 'v_rad_1st': array([1.01566521, 3.92073262])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.26865481, 1.10458394]), 'N_1st': array([4.94916723e+10, 1.16620900e+11]), 'v_rad_1st': array([1.01566521, 3.92073262])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.26864216, 1.10458394]), 'N_1st': array([4.94921672e+10, 1.16620900e+11]), 'v_rad_1st': array([1.01566521, 3.92073262])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.26864216, 1.10458394]), 'N_1st': array([4.94916723e+10, 1.16620900e+11]), 'v_rad_1st': array([1.01567537, 3.92073262])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.26864216, 1.10459827]), 'N_1st': array([4.94916723e+10, 1.16620900e+11]), 'v_rad_1st': array([1.01566521, 3.92073262])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.26864216, 1.10458394]), 'N_1st': array([4.94916723e+10, 1.16622066e+11]), 'v_rad_1st': array([1.01566521, 3.92073262])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([4.26864216, 1.10458394]), 'N_1st': array([4.94916723e+10, 1.16620900e+11]), 'v_rad_1st': array([1.01566521, 3.92077182])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.32274325, 1.13532655]), 'N_1st': array([6.85048919e+09, 1.58364541e+11]), 'v_rad_1st': array([-0.81383085,  3.46237202])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.32275655, 1.13532655]), 'N_1st': array([6.85048919e+09, 1.58364541e+11]), 'v_rad_1st': array([-0.81383085,  3.46237202])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.32274325, 1.13532655]), 'N_1st': array([6.85055770e+09, 1.58364541e+11]), 'v_rad_1st': array([-0.81383085,  3.46237202])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.32274325, 1.13532655]), 'N_1st': array([6.85048919e+09, 1.58364541e+11]), 'v_rad_1st': array([-0.81382271,  3.46237202])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.32274325, 1.13534077]), 'N_1st': array([6.85048919e+09, 1.58364541e+11]), 'v_rad_1st': array([-0.81383085,  3.46237202])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.32274325, 1.13532655]), 'N_1st': array([6.85048919e+09, 1.58366125e+11]), 'v_rad_1st': array([-0.81383085,  3.46237202])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([1.32274325, 1.13532655]), 'N_1st': array([6.85048919e+09, 1.58364541e+11]), 'v_rad_1st': array([-0.81383085,  3.46240665])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.39565975, 1.05874969]), 'N_1st': array([2.50947310e+10, 1.34116145e+11]), 'v_rad_1st': array([1.13014676, 3.63396512])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.39564612, 1.05874969]), 'N_1st': array([2.50947310e+10, 1.34116145e+11]), 'v_rad_1st': array([1.13014676, 3.63396512])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.39565975, 1.05874969]), 'N_1st': array([2.50949820e+10, 1.34116145e+11]), 'v_rad_1st': array([1.13014676, 3.63396512])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.39565975, 1.05874969]), 'N_1st': array([2.50947310e+10, 1.34116145e+11]), 'v_rad_1st': array([1.13015806, 3.63396512])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.39565975, 1.05876419]), 'N_1st': array([2.50947310e+10, 1.34116145e+11]), 'v_rad_1st': array([1.13014676, 3.63396512])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.39565975, 1.05874969]), 'N_1st': array([2.50947310e+10, 1.34117487e+11]), 'v_rad_1st': array([1.13014676, 3.63396512])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.39565975, 1.05874969]), 'N_1st': array([2.50947310e+10, 1.34116145e+11]), 'v_rad_1st': array([1.13014676, 3.63400146])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([2.87528851, 1.07938992]), 'N_1st': array([2.32972037e+10, 1.52973869e+11]), 'v_rad_1st': array([-1.58265327,  3.63382354])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.16738625, 1.07718713]), 'N_1st': array([2.97741956e+10, 1.44546658e+11]), 'v_rad_1st': array([-0.05172214,  3.6426074 ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.16735955, 1.07718713]), 'N_1st': array([2.97741956e+10, 1.44546658e+11]), 'v_rad_1st': array([-0.05172214,  3.6426074 ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.16738625, 1.07718713]), 'N_1st': array([2.97744933e+10, 1.44546658e+11]), 'v_rad_1st': array([-0.05172214,  3.6426074 ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.16738625, 1.07718713]), 'N_1st': array([2.97741956e+10, 1.44546658e+11]), 'v_rad_1st': array([-0.05172162,  3.6426074 ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.16738625, 1.07720156]), 'N_1st': array([2.97741956e+10, 1.44546658e+11]), 'v_rad_1st': array([-0.05172214,  3.6426074 ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.16738625, 1.07718713]), 'N_1st': array([2.97741956e+10, 1.44548104e+11]), 'v_rad_1st': array([-0.05172214,  3.6426074 ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([5.16738625, 1.07718713]), 'N_1st': array([2.97741956e+10, 1.44546658e+11]), 'v_rad_1st': array([-0.05172214,  3.64264383])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.50156743, 0.99013314]), 'N_1st': array([2.55384056e+10, 1.41692394e+11]), 'v_rad_1st': array([-0.29321718,  3.59367627])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.5016312 , 0.99013314]), 'N_1st': array([2.55384056e+10, 1.41692394e+11]), 'v_rad_1st': array([-0.29321718,  3.59367627])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.50156743, 0.99013314]), 'N_1st': array([2.55386609e+10, 1.41692394e+11]), 'v_rad_1st': array([-0.29321718,  3.59367627])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.50156743, 0.99013314]), 'N_1st': array([2.55384056e+10, 1.41692394e+11]), 'v_rad_1st': array([-0.29321425,  3.59367627])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.50156743, 0.99014782]), 'N_1st': array([2.55384056e+10, 1.41692394e+11]), 'v_rad_1st': array([-0.29321718,  3.59367627])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.50156743, 0.99013314]), 'N_1st': array([2.55384056e+10, 1.41693811e+11]), 'v_rad_1st': array([-0.29321718,  3.59367627])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.50156743, 0.99013314]), 'N_1st': array([2.55384056e+10, 1.41692394e+11]), 'v_rad_1st': array([-0.29321718,  3.5937122 ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.41634923, 0.67404114]), 'N_1st': array([2.50277514e+10, 1.48037622e+11]), 'v_rad_1st': array([-0.02960448,  3.61575987])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.41640293, 0.67404114]), 'N_1st': array([2.50277514e+10, 1.48037622e+11]), 'v_rad_1st': array([-0.02960448,  3.61575987])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.41634923, 0.67404114]), 'N_1st': array([2.50280017e+10, 1.48037622e+11]), 'v_rad_1st': array([-0.02960448,  3.61575987])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.41634923, 0.67404114]), 'N_1st': array([2.50277514e+10, 1.48037622e+11]), 'v_rad_1st': array([-0.02960418,  3.61575987])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.41634923, 0.67405571]), 'N_1st': array([2.50277514e+10, 1.48037622e+11]), 'v_rad_1st': array([-0.02960448,  3.61575987])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.41634923, 0.67404114]), 'N_1st': array([2.50277514e+10, 1.48039102e+11]), 'v_rad_1st': array([-0.02960448,  3.61575987])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.41634923, 0.67404114]), 'N_1st': array([2.50277514e+10, 1.48037622e+11]), 'v_rad_1st': array([-0.02960448,  3.61579602])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.37057882, 0.5209442 ]), 'N_1st': array([2.61766183e+10, 1.73734132e+11]), 'v_rad_1st': array([0.03645205, 3.60760517])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.37062628, 0.5209442 ]), 'N_1st': array([2.61766183e+10, 1.73734132e+11]), 'v_rad_1st': array([0.03645205, 3.60760517])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.37057882, 0.5209442 ]), 'N_1st': array([2.61768801e+10, 1.73734132e+11]), 'v_rad_1st': array([0.03645205, 3.60760517])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.37057882, 0.5209442 ]), 'N_1st': array([2.61766183e+10, 1.73734132e+11]), 'v_rad_1st': array([0.03645241, 3.60760517])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.37057882, 0.52095778]), 'N_1st': array([2.61766183e+10, 1.73734132e+11]), 'v_rad_1st': array([0.03645205, 3.60760517])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.37057882, 0.5209442 ]), 'N_1st': array([2.61766183e+10, 1.73735869e+11]), 'v_rad_1st': array([0.03645205, 3.60760517])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.37057882, 0.5209442 ]), 'N_1st': array([2.61766183e+10, 1.73734132e+11]), 'v_rad_1st': array([0.03645205, 3.60764124])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2854534 , 0.33604596]), 'N_1st': array([2.63477350e+10, 2.09379303e+11]), 'v_rad_1st': array([0.08097072, 3.6089716 ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.27778621, 0.50983102]), 'N_1st': array([2.63487998e+10, 1.76144936e+11]), 'v_rad_1st': array([0.07198202, 3.60733335])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.27781779, 0.50983102]), 'N_1st': array([2.63487998e+10, 1.76144936e+11]), 'v_rad_1st': array([0.07198202, 3.60733335])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.27778621, 0.50983102]), 'N_1st': array([2.63490633e+10, 1.76144936e+11]), 'v_rad_1st': array([0.07198202, 3.60733335])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.27778621, 0.50983102]), 'N_1st': array([2.63487998e+10, 1.76144936e+11]), 'v_rad_1st': array([0.07198274, 3.60733335])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.27778621, 0.50984448]), 'N_1st': array([2.63487998e+10, 1.76144936e+11]), 'v_rad_1st': array([0.07198202, 3.60733335])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.27778621, 0.50983102]), 'N_1st': array([2.63487998e+10, 1.76146698e+11]), 'v_rad_1st': array([0.07198202, 3.60733335])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.27778621, 0.50983102]), 'N_1st': array([2.63487998e+10, 1.76144936e+11]), 'v_rad_1st': array([0.07198202, 3.60736942])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.3158594, 0.4989469]), 'N_1st': array([2.62918171e+10, 1.75461132e+11]), 'v_rad_1st': array([0.0854378 , 3.61269649])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.29556804, 0.50647489]), 'N_1st': array([2.64915776e+10, 1.77219652e+11]), 'v_rad_1st': array([0.07951192, 3.61414674])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.29560318, 0.50647489]), 'N_1st': array([2.64915776e+10, 1.77219652e+11]), 'v_rad_1st': array([0.07951192, 3.61414674])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.29556804, 0.50647489]), 'N_1st': array([2.64918426e+10, 1.77219652e+11]), 'v_rad_1st': array([0.07951192, 3.61414674])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.29556804, 0.50647489]), 'N_1st': array([2.64915776e+10, 1.77219652e+11]), 'v_rad_1st': array([0.07951271, 3.61414674])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.29556804, 0.50648831]), 'N_1st': array([2.64915776e+10, 1.77219652e+11]), 'v_rad_1st': array([0.07951192, 3.61414674])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.29556804, 0.50647489]), 'N_1st': array([2.64915776e+10, 1.77221424e+11]), 'v_rad_1st': array([0.07951192, 3.61414674])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.29556804, 0.50647489]), 'N_1st': array([2.64915776e+10, 1.77219652e+11]), 'v_rad_1st': array([0.07951192, 3.61418289])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28726198, 0.50821188]), 'N_1st': array([2.65840815e+10, 1.78154631e+11]), 'v_rad_1st': array([0.08075414, 3.61647525])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28729551, 0.50821188]), 'N_1st': array([2.65840815e+10, 1.78154631e+11]), 'v_rad_1st': array([0.08075414, 3.61647525])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28726198, 0.50821188]), 'N_1st': array([2.65843473e+10, 1.78154631e+11]), 'v_rad_1st': array([0.08075414, 3.61647525])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28726198, 0.50821188]), 'N_1st': array([2.65840815e+10, 1.78154631e+11]), 'v_rad_1st': array([0.08075495, 3.61647525])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28726198, 0.50822532]), 'N_1st': array([2.65840815e+10, 1.78154631e+11]), 'v_rad_1st': array([0.08075414, 3.61647525])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28726198, 0.50821188]), 'N_1st': array([2.65840815e+10, 1.78156412e+11]), 'v_rad_1st': array([0.08075414, 3.61647525])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28726198, 0.50821188]), 'N_1st': array([2.65840815e+10, 1.78154631e+11]), 'v_rad_1st': array([0.08075414, 3.61651141])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28257769, 0.50845408]), 'N_1st': array([2.66292622e+10, 1.78559517e+11]), 'v_rad_1st': array([0.08114292, 3.61699558])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28261027, 0.50845408]), 'N_1st': array([2.66292622e+10, 1.78559517e+11]), 'v_rad_1st': array([0.08114292, 3.61699558])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28257769, 0.50845408]), 'N_1st': array([2.66295285e+10, 1.78559517e+11]), 'v_rad_1st': array([0.08114292, 3.61699558])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28257769, 0.50845408]), 'N_1st': array([2.66292622e+10, 1.78559517e+11]), 'v_rad_1st': array([0.08114373, 3.61699558])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28257769, 0.50846753]), 'N_1st': array([2.66292622e+10, 1.78559517e+11]), 'v_rad_1st': array([0.08114292, 3.61699558])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28257769, 0.50845408]), 'N_1st': array([2.66292622e+10, 1.78561302e+11]), 'v_rad_1st': array([0.08114292, 3.61699558])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28257769, 0.50845408]), 'N_1st': array([2.66292622e+10, 1.78559517e+11]), 'v_rad_1st': array([0.08114292, 3.61703175])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.284549  , 0.50820157]), 'N_1st': array([2.66422997e+10, 1.78821773e+11]), 'v_rad_1st': array([0.081461 , 3.6173514])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28458198, 0.50820157]), 'N_1st': array([2.66422997e+10, 1.78821773e+11]), 'v_rad_1st': array([0.081461 , 3.6173514])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.284549  , 0.50820157]), 'N_1st': array([2.66425661e+10, 1.78821773e+11]), 'v_rad_1st': array([0.081461 , 3.6173514])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.284549  , 0.50820157]), 'N_1st': array([2.66422997e+10, 1.78821773e+11]), 'v_rad_1st': array([0.08146182, 3.6173514 ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.284549  , 0.50821501]), 'N_1st': array([2.66422997e+10, 1.78821773e+11]), 'v_rad_1st': array([0.081461 , 3.6173514])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.284549  , 0.50820157]), 'N_1st': array([2.66422997e+10, 1.78823561e+11]), 'v_rad_1st': array([0.081461 , 3.6173514])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.284549  , 0.50820157]), 'N_1st': array([2.66422997e+10, 1.78821773e+11]), 'v_rad_1st': array([0.081461  , 3.61738757])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28550969, 0.50811109]), 'N_1st': array([2.66468741e+10, 1.78967412e+11]), 'v_rad_1st': array([0.08158968, 3.61755179])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28554286, 0.50811109]), 'N_1st': array([2.66468741e+10, 1.78967412e+11]), 'v_rad_1st': array([0.08158968, 3.61755179])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28550969, 0.50811109]), 'N_1st': array([2.66471406e+10, 1.78967412e+11]), 'v_rad_1st': array([0.08158968, 3.61755179])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28550969, 0.50811109]), 'N_1st': array([2.66468741e+10, 1.78967412e+11]), 'v_rad_1st': array([0.0815905 , 3.61755179])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28550969, 0.50812453]), 'N_1st': array([2.66468741e+10, 1.78967412e+11]), 'v_rad_1st': array([0.08158968, 3.61755179])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28550969, 0.50811109]), 'N_1st': array([2.66468741e+10, 1.78969202e+11]), 'v_rad_1st': array([0.08158968, 3.61755179])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28550969, 0.50811109]), 'N_1st': array([2.66468741e+10, 1.78967412e+11]), 'v_rad_1st': array([0.08158968, 3.61758796])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28479639, 0.50829913]), 'N_1st': array([2.6654105e+10, 1.7916114e+11]), 'v_rad_1st': array([0.08175616, 3.61770226])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28482942, 0.50829913]), 'N_1st': array([2.6654105e+10, 1.7916114e+11]), 'v_rad_1st': array([0.08175616, 3.61770226])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28479639, 0.50829913]), 'N_1st': array([2.66543715e+10, 1.79161140e+11]), 'v_rad_1st': array([0.08175616, 3.61770226])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28479639, 0.50829913]), 'N_1st': array([2.6654105e+10, 1.7916114e+11]), 'v_rad_1st': array([0.08175698, 3.61770226])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28479639, 0.50831257]), 'N_1st': array([2.6654105e+10, 1.7916114e+11]), 'v_rad_1st': array([0.08175616, 3.61770226])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28479639, 0.50829913]), 'N_1st': array([2.66541050e+10, 1.79162932e+11]), 'v_rad_1st': array([0.08175616, 3.61770226])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28479639, 0.50829913]), 'N_1st': array([2.6654105e+10, 1.7916114e+11]), 'v_rad_1st': array([0.08175616, 3.61773844])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28559728, 0.5082161 ]), 'N_1st': array([2.66585668e+10, 1.79345255e+11]), 'v_rad_1st': array([0.08190166, 3.61787199])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28563047, 0.5082161 ]), 'N_1st': array([2.66585668e+10, 1.79345255e+11]), 'v_rad_1st': array([0.08190166, 3.61787199])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28559728, 0.5082161 ]), 'N_1st': array([2.66588334e+10, 1.79345255e+11]), 'v_rad_1st': array([0.08190166, 3.61787199])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28559728, 0.5082161 ]), 'N_1st': array([2.66585668e+10, 1.79345255e+11]), 'v_rad_1st': array([0.08190248, 3.61787199])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28559728, 0.50822955]), 'N_1st': array([2.66585668e+10, 1.79345255e+11]), 'v_rad_1st': array([0.08190166, 3.61787199])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28559728, 0.5082161 ]), 'N_1st': array([2.66585668e+10, 1.79347048e+11]), 'v_rad_1st': array([0.08190166, 3.61787199])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28559728, 0.5082161 ]), 'N_1st': array([2.66585668e+10, 1.79345255e+11]), 'v_rad_1st': array([0.08190166, 3.61790817])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28488322, 0.50839612]), 'N_1st': array([2.66656893e+10, 1.79579744e+11]), 'v_rad_1st': array([0.08207416, 3.61800815])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28491627, 0.50839612]), 'N_1st': array([2.66656893e+10, 1.79579744e+11]), 'v_rad_1st': array([0.08207416, 3.61800815])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28488322, 0.50839612]), 'N_1st': array([2.66659559e+10, 1.79579744e+11]), 'v_rad_1st': array([0.08207416, 3.61800815])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28488322, 0.50839612]), 'N_1st': array([2.66656893e+10, 1.79579744e+11]), 'v_rad_1st': array([0.08207498, 3.61800815])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28488322, 0.50840957]), 'N_1st': array([2.66656893e+10, 1.79579744e+11]), 'v_rad_1st': array([0.08207416, 3.61800815])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28488322, 0.50839612]), 'N_1st': array([2.66656893e+10, 1.79581539e+11]), 'v_rad_1st': array([0.08207416, 3.61800815])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28488322, 0.50839612]), 'N_1st': array([2.66656893e+10, 1.79579744e+11]), 'v_rad_1st': array([0.08207416, 3.61804433])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28584611, 0.50826002]), 'N_1st': array([2.66680557e+10, 1.79743941e+11]), 'v_rad_1st': array([0.08218715, 3.61812268])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28587935, 0.50826002]), 'N_1st': array([2.66680557e+10, 1.79743941e+11]), 'v_rad_1st': array([0.08218715, 3.61812268])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28584611, 0.50826002]), 'N_1st': array([2.66683224e+10, 1.79743941e+11]), 'v_rad_1st': array([0.08218715, 3.61812268])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28584611, 0.50826002]), 'N_1st': array([2.66680557e+10, 1.79743941e+11]), 'v_rad_1st': array([0.08218798, 3.61812268])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28584611, 0.50827346]), 'N_1st': array([2.66680557e+10, 1.79743941e+11]), 'v_rad_1st': array([0.08218715, 3.61812268])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28584611, 0.50826002]), 'N_1st': array([2.66680557e+10, 1.79745739e+11]), 'v_rad_1st': array([0.08218715, 3.61812268])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28584611, 0.50826002]), 'N_1st': array([2.66680557e+10, 1.79743941e+11]), 'v_rad_1st': array([0.08218715, 3.61815886])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28544135, 0.50836316]), 'N_1st': array([2.66691942e+10, 1.79838442e+11]), 'v_rad_1st': array([0.08223355, 3.61814412])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2854745 , 0.50836316]), 'N_1st': array([2.66691942e+10, 1.79838442e+11]), 'v_rad_1st': array([0.08223355, 3.61814412])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28544135, 0.50836316]), 'N_1st': array([2.66694609e+10, 1.79838442e+11]), 'v_rad_1st': array([0.08223355, 3.61814412])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28544135, 0.50836316]), 'N_1st': array([2.66691942e+10, 1.79838442e+11]), 'v_rad_1st': array([0.08223437, 3.61814412])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28544135, 0.50837661]), 'N_1st': array([2.66691942e+10, 1.79838442e+11]), 'v_rad_1st': array([0.08223355, 3.61814412])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28544135, 0.50836316]), 'N_1st': array([2.66691942e+10, 1.79840240e+11]), 'v_rad_1st': array([0.08223355, 3.61814412])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28544135, 0.50836316]), 'N_1st': array([2.66691942e+10, 1.79838442e+11]), 'v_rad_1st': array([0.08223355, 3.6181803 ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28445898, 0.50852876]), 'N_1st': array([2.66735662e+10, 1.79961154e+11]), 'v_rad_1st': array([0.08232783, 3.61818002])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28502839, 0.508437  ]), 'N_1st': array([2.66705657e+10, 1.79892617e+11]), 'v_rad_1st': array([0.0822711 , 3.61815887])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28506146, 0.508437  ]), 'N_1st': array([2.66705657e+10, 1.79892617e+11]), 'v_rad_1st': array([0.0822711 , 3.61815887])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28502839, 0.508437  ]), 'N_1st': array([2.66708324e+10, 1.79892617e+11]), 'v_rad_1st': array([0.0822711 , 3.61815887])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28502839, 0.508437  ]), 'N_1st': array([2.66705657e+10, 1.79892617e+11]), 'v_rad_1st': array([0.08227192, 3.61815887])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28502839, 0.50845045]), 'N_1st': array([2.66705657e+10, 1.79892617e+11]), 'v_rad_1st': array([0.0822711 , 3.61815887])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28502839, 0.508437  ]), 'N_1st': array([2.66705657e+10, 1.79894415e+11]), 'v_rad_1st': array([0.0822711 , 3.61815887])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28502839, 0.508437  ]), 'N_1st': array([2.66705657e+10, 1.79892617e+11]), 'v_rad_1st': array([0.0822711 , 3.61819505])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28544493, 0.5083637 ]), 'N_1st': array([2.66711612e+10, 1.79927176e+11]), 'v_rad_1st': array([0.08229228, 3.61819977])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2852356 , 0.50840085]), 'N_1st': array([2.66709276e+10, 1.79910032e+11]), 'v_rad_1st': array([0.08228244, 3.61818115])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28526872, 0.50840085]), 'N_1st': array([2.66709276e+10, 1.79910032e+11]), 'v_rad_1st': array([0.08228244, 3.61818115])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2852356 , 0.50840085]), 'N_1st': array([2.66711943e+10, 1.79910032e+11]), 'v_rad_1st': array([0.08228244, 3.61818115])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2852356 , 0.50840085]), 'N_1st': array([2.66709276e+10, 1.79910032e+11]), 'v_rad_1st': array([0.08228326, 3.61818115])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2852356, 0.5084143]), 'N_1st': array([2.66709276e+10, 1.79910032e+11]), 'v_rad_1st': array([0.08228244, 3.61818115])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2852356 , 0.50840085]), 'N_1st': array([2.66709276e+10, 1.79911831e+11]), 'v_rad_1st': array([0.08228244, 3.61818115])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2852356 , 0.50840085]), 'N_1st': array([2.66709276e+10, 1.79910032e+11]), 'v_rad_1st': array([0.08228244, 3.61821733])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28502297, 0.50843769]), 'N_1st': array([2.66713477e+10, 1.79927027e+11]), 'v_rad_1st': array([0.08229427, 3.61818177])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2851652 , 0.50841316]), 'N_1st': array([2.66710529e+10, 1.79915735e+11]), 'v_rad_1st': array([0.08228625, 3.61818129])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2851983 , 0.50841316]), 'N_1st': array([2.66710529e+10, 1.79915735e+11]), 'v_rad_1st': array([0.08228625, 3.61818129])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2851652 , 0.50841316]), 'N_1st': array([2.66713197e+10, 1.79915735e+11]), 'v_rad_1st': array([0.08228625, 3.61818129])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2851652 , 0.50841316]), 'N_1st': array([2.66710529e+10, 1.79915735e+11]), 'v_rad_1st': array([0.08228707, 3.61818129])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2851652, 0.5084266]), 'N_1st': array([2.66710529e+10, 1.79915735e+11]), 'v_rad_1st': array([0.08228625, 3.61818129])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2851652 , 0.50841316]), 'N_1st': array([2.66710529e+10, 1.79917534e+11]), 'v_rad_1st': array([0.08228625, 3.61818129])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2851652 , 0.50841316]), 'N_1st': array([2.66710529e+10, 1.79915735e+11]), 'v_rad_1st': array([0.08228625, 3.61821747])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2852309 , 0.50839841]), 'N_1st': array([2.66711712e+10, 1.79921457e+11]), 'v_rad_1st': array([0.08228998, 3.61818943])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519631, 0.50840618]), 'N_1st': array([2.66711108e+10, 1.79918450e+11]), 'v_rad_1st': array([0.08228804, 3.61818519])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28522942, 0.50840618]), 'N_1st': array([2.66711108e+10, 1.79918450e+11]), 'v_rad_1st': array([0.08228804, 3.61818519])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519631, 0.50840618]), 'N_1st': array([2.66713775e+10, 1.79918450e+11]), 'v_rad_1st': array([0.08228804, 3.61818519])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519631, 0.50840618]), 'N_1st': array([2.66711108e+10, 1.79918450e+11]), 'v_rad_1st': array([0.08228886, 3.61818519])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519631, 0.50841963]), 'N_1st': array([2.66711108e+10, 1.79918450e+11]), 'v_rad_1st': array([0.08228804, 3.61818519])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519631, 0.50840618]), 'N_1st': array([2.66711108e+10, 1.79920250e+11]), 'v_rad_1st': array([0.08228804, 3.61818519])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519631, 0.50840618]), 'N_1st': array([2.66711108e+10, 1.79918450e+11]), 'v_rad_1st': array([0.08228804, 3.61822138])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28512481, 0.50841584]), 'N_1st': array([2.66712325e+10, 1.79923828e+11]), 'v_rad_1st': array([0.08229167, 3.61818511])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28517676, 0.50840883]), 'N_1st': array([2.66711427e+10, 1.79919927e+11]), 'v_rad_1st': array([0.08228902, 3.61818516])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519041, 0.50840698]), 'N_1st': array([2.66711203e+10, 1.79918897e+11]), 'v_rad_1st': array([0.08228833, 3.61818518])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28522352, 0.50840698]), 'N_1st': array([2.66711203e+10, 1.79918897e+11]), 'v_rad_1st': array([0.08228833, 3.61818518])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519041, 0.50840698]), 'N_1st': array([2.66713870e+10, 1.79918897e+11]), 'v_rad_1st': array([0.08228833, 3.61818518])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519041, 0.50840698]), 'N_1st': array([2.66711203e+10, 1.79918897e+11]), 'v_rad_1st': array([0.08228916, 3.61818518])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519041, 0.50842043]), 'N_1st': array([2.66711203e+10, 1.79918897e+11]), 'v_rad_1st': array([0.08228833, 3.61818518])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519041, 0.50840698]), 'N_1st': array([2.66711203e+10, 1.79920696e+11]), 'v_rad_1st': array([0.08228833, 3.61818518])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519041, 0.50840698]), 'N_1st': array([2.66711203e+10, 1.79918897e+11]), 'v_rad_1st': array([0.08228833, 3.61822137])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28518473, 0.50840575]), 'N_1st': array([2.66711302e+10, 1.79919358e+11]), 'v_rad_1st': array([0.08228864, 3.61818586])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28518887, 0.50840665]), 'N_1st': array([2.66711230e+10, 1.79919022e+11]), 'v_rad_1st': array([0.08228842, 3.61818537])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519   , 0.50840689]), 'N_1st': array([2.66711210e+10, 1.79918931e+11]), 'v_rad_1st': array([0.08228836, 3.61818523])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.2851903 , 0.50840696]), 'N_1st': array([2.66711205e+10, 1.79918906e+11]), 'v_rad_1st': array([0.08228834, 3.6181852 ])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519041, 0.50840698]), 'N_1st': array([2.66711203e+10, 1.79918897e+11]), 'v_rad_1st': array([0.08228833, 3.61818518])}
# master_kwargs {'lambda_1st': array([7698.965]), 'f_1st': array([0.3331]), 'gamma_1st': array([37400000.]), 'b_1st': array([0.28519041, 0.50840698]), 'N_1st': array([2.66711203e+10, 1.79918897e+11]), 'v_rad_1st': array([0.08228833, 3.61818518])}
# Name              Value      Min      Max   Stderr     Vary     Expr Brute_Step
# N_0_0          2.667e+10        0      inf 2.136e+09     True     None     None
# N_0_1          1.799e+11        0      inf 1.073e+10     True     None     None
# b_0_0            0.2852      0.2      5.5  0.02974     True     None     None
# b_0_1            0.5084      0.2      5.5  0.04945     True     None     None
# f_0_0            0.3331     -inf      inf        0    False     None     None
# gamma_0_0      3.74e+07     -inf      inf        0    False     None     None
# knot_y_0          1.004        0      inf        0    False     None     None
# knot_y_1          1.006        0      inf        0    False     None     None
# knot_y_2          1.006        0      inf        0    False     None     None
# knot_y_3          1.006        0      inf        0    False     None     None
# knot_y_4         0.9939        0      inf        0    False     None     None
# knot_y_5         0.9962        0      inf        0    False     None     None
# knot_y_6         0.9985        0      inf        0    False     None     None
# lambda_0_0         7699     -inf      inf        0    False     None     None
# n_component_0         2     -inf      inf        0    False     None     None
# n_species             1     -inf      inf        0    False     None     None
# n_step               25     -inf      inf        0    False     None     None
# n_trans_0             1     -inf      inf        0    False     None     None
# v_rad_0_0       0.08229     -inf      inf  0.06224     True     None     None
# v_rad_0_1         3.618     -inf      inf   0.0151     True     None     None
# v_resolution          3     -inf      inf        0    False     None     None
# chi-square value  32.883403530851474
# reduced chi-square value  1.2647462896481336
# FITTING RESULT : True
#
# Fit success:        True
# Chi square:         32.8834
# Reduced chi square: 1.2647
# Std of residuals:   0.00399

# %%
params = fitresult.params

print(f'Star: {star_name}')
print('=' * 40)
for i, mol in enumerate(molecules):
    print(f'\nSpecies {i+1}: {mol}')
    comp_idx = 0
    while f'b_{i}_{comp_idx}' in params:
        b = params[f'b_{i}_{comp_idx}']
        N = params[f'N_{i}_{comp_idx}']
        v = params[f'v_rad_{i}_{comp_idx}']
        print(f'  Component {comp_idx+1}:')
        for p, label in [(b, 'b    '), (N, 'N    '), (v, 'v_rad')]:
            if p.stderr is None:
                print(f'    {label}: {p.value:.4g}  (fixed or tied)')
            else:
                pct = abs(p.stderr / p.value) * 100 if p.value != 0 else 0
                print(f'    {label}: {p.value:.4g} +/- {p.stderr:.4g}  ({pct:.2f}%)')
        comp_idx += 1

print(f'\nChi square:         {fitresult.chisqr:.4f}')
print(f'Reduced chi square: {fitresult.redchi:.4f}')
# Out:
# Star: HD 34748
# ========================================
#
# Species 1: K_7699
#   Component 1:
#     b    : 0.2852 +/- 0.02974  (10.43%)
#     N    : 2.667e+10 +/- 2.136e+09  (8.01%)
#     v_rad: 0.08229 +/- 0.06224  (75.64%)
#   Component 2:
#     b    : 0.5084 +/- 0.04945  (9.73%)
#     N    : 1.799e+11 +/- 1.073e+10  (5.96%)
#     v_rad: 3.618 +/- 0.0151  (0.42%)
#
# Chi square:         32.8834
# Reduced chi square: 1.2647

# %%
# Top: data + continuum + total fit. Bottom: normalized flux + absorption model.
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True,
                         gridspec_kw={'height_ratios': [2, 1, 1]})

wave_list = transformations.rv_to_wavelength(np.array(species_params[0]['v_rad']), target_wave)

for i, mol in enumerate(molecules):
    p = species_params[i]
ax_top = axes[0]
ax_top.plot(wave_fit, flux_fit, color='black', lw=1, label='co added data')
ax_top.plot(wave_fit, continuum, color='red', lw=1.2, label='fitted continuum')
ax_top.plot(wave_fit, fitresult.best_fit, color='green', lw=1.2,
            label=f'total fit (continuum x absorption) — {len(p["b"])} component(s)')
ax_top.axvspan(*absorption_range, color='red', alpha=0.1)
ax_top.set_ylabel('Flux')
ax_top.set_title(f'{star_name} fit result')
ax_top.legend(loc='best')
ax_top.vlines(wave_list, flux_fit.min(), flux_fit.max(), colors='purple', linestyles='--', label='v_rad positions')

ax_bot = axes[1]
ax_bot.plot(wave_fit, normalized_flux, color='black', lw=1, label='normalized flux')
ax_bot.plot(wave_fit, fitresult.best_fit / continuum, color='green', lw=1.2,
            label='absorption model')
ax_bot.axhline(1.0, color='gray', lw=0.8, linestyle=':')
ax_bot.axvspan(*absorption_range, color='red', alpha=0.1)
ax_bot.set_ylabel('Normalized flux')
ax_bot.legend()

ax_bot = axes[2]
ax_bot.plot(wave_fit, flux_fit - fitresult.best_fit, color='black', lw=1, label='residual (data minus fit)')
ax_bot.axhline(0, color='red', lw=0.8)
ax_bot.fill_between(wave_fit, -residual_std, residual_std, color='gray', alpha=0.3,
                 label=f'+/- 1 sigma ({residual_std:.4f})')
ax_bot.set_xlabel('Wavelength (Å)')
ax_bot.set_ylabel('Residual (data minus fit)')
ax_bot.legend(loc='lower left')


plt.tight_layout()
plt.savefig(r"C:\Users\User\Downloads\PYTHON PROJECTS\edibles\edibles\projects\GUI\KI_fits_self\results\plots\HD 34748.png")
plt.show()

# %%
# Residuals: data minus total fit. Should look like noise centered on zero.
plt.figure(figsize=(10, 3))
plt.plot(wave_fit, flux_fit - fitresult.best_fit, color='black', lw=1)
plt.axhline(0, color='red', lw=0.8)
plt.fill_between(wave_fit, -residual_std, residual_std, color='gray', alpha=0.3,
                 label=f'+/- 1 sigma ({residual_std:.4f})')
plt.xlabel('Wavelength (A)')
plt.ylabel('Residual (data minus fit)')
plt.title('Residuals')
plt.legend()
plt.show()

# %%
fitresult.fit_report()
with open(r"C:\Users\User\Downloads\PYTHON PROJECTS\edibles\edibles\projects\GUI\KI_fits_self\results\HD 34748_params.txt", 'w') as f:
 f.write(fitresult.fit_report())
